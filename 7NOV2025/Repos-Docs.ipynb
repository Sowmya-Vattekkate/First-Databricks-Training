# %% [markdown]
# ### Databrics REPOS Hands on
# #### Created Repo in Github
# #### Created Git folder in Databricks
# #### Configure the connection from databricks to git hub --> Going to Settings --> Linked Accounts
